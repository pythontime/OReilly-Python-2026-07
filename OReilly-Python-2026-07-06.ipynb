# %% [markdown]
# # Agenda
#
# 1. Fundamentals and core principles
#     - What is a programming language?
#     - What is Python?
#     - Values and variables
#     - Displaying things with `print`
#     - Getting input from the user with `input`
#     - Making decisions with `if` and `else`
#     - Numbers (`int` and `float`)
#     - Text in Python (`str`)
#     - Methods in Python -- another form of verb
# 2. Loops, lists, and tuples
#     - Loops (`for` and `while`)
#     - Lists -- what they are, how to build them, and how to use them
#     - Turning strings into lists, and back
#     - Tuples -- another sequence (sort of like lists)
# 3. Dictionaries and files
#     - Dicts, and why they're the most important data structure in Python
#     - Files -- reading from them, and a bit of writing to them
# 4. Functions
#     - What is a function?
#     - Defining functions
#     - Arguments and parameters
#     - Return values
#     - Local and global variables
# 5. Modules and packages
#     - Using modules
#     - The standard library that comes with Python
#     - Using third-party packages from PyPI
#     - What's next -- where do you go from here?

# %% [markdown]
# # Jupyter and writing Python
#
# If you want to program in Python, then you're going to need:
#
# 1. Python installed somewhere
# 2. An editor that lets you write Python
#
# You can install Python on your computer (just go to https://python.org). But if you're new to Python, then installing it can be a bit difficult. And then installing an editor can be even more difficult.
#
# I use Jupyter, which is a "notebook" environment. I'm typing right now into a "cell" in a "notebook." This is meant for experimenting. But installing it can be a bit tough.
#
# The easiest way for you to get star
